# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
print(combined_data.head())
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
# Checking the number of unique mice
number_of_mice = combined_data["Mouse ID"].nunique()
print(f"Number of unique mice: {number_of_mice}")
# Out:
# Number of unique mice: 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mouse_id = duplicate_mice[duplicate_mice.duplicated(['Mouse ID', 'Timepoint'], keep=False)]['Mouse ID'].unique()
duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_data = combined_data[combined_data['Mouse ID'].isin(duplicate_mouse_id)]
duplicate_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = combined_data[combined_data['Mouse ID'] != 'g989']
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
#Display the number of unique mice IDs after g989 removed from 
num_clean_mice = clean_data['Mouse ID'].nunique()
print(f"Number of mice in the clean DataFrame: {num_clean_mice}")
# Out:
# Number of mice in the clean DataFrame: 248

# %%
clean_data_df =

# %%
#mouse_g989_removed = (num_unique_mice_df['Mouse ID'] != 'g989')
#mouse_g989_removed

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.`
#Skipping

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

clean_data_df = pd.DataFrame(clean_data)

# Group by Drug Regimen and count the number of rows
regimen_counts = clean_data_df.groupby('Drug Regimen').size()

# Generate the bar plot
regimen_counts.plot(kind='bar', figsize=(10, 5), color='blue')
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')
plt.xticks(rotation=45)
plt.show()

# %%
#Preparing data: List Option, Turning dataframe into a list of lists to use with pyplot.
list_of_lists = clean_data_df.values.tolist()
list_of_lists
# Out:
# [['k403', 'Ramicane', 'Male', 21, 16, 0, 45.0, 0],
#  ['k403', 'Ramicane', 'Male', 21, 16, 5, 38.82589807, 0],
#  ['k403', 'Ramicane', 'Male', 21, 16, 10, 35.01427146, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 15, 34.22399174, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 20, 32.99772858, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 25, 33.46457735, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 30, 31.09949753, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 35, 26.54699343, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 40, 24.36550471, 1],
#  ['k403', 'Ramicane', 'Male', 21, 16, 45, 22.05012627, 1],
#  ['s185', 'Capomulin', 'Female', 3, 17, 0, 45.0, 0],
#  ['s185', 'Capomulin', 'Female', 3, 17, 5, 43.87849569, 0],
#  ['s185', 'Capomulin', 'Female', 3, 17, 10, 37.61494768, 0],
#  ['s185', 'Capomulin', 'Female', 3, 17, 15, 38.17723195, 0],
#  ['s185', 'Capomulin', 'Female', 3, 17, 20, 36.86687576, 0],
#  ['s185', 'Capomulin', 'Female', 3, 17, 25, 33.94994037, 0],
#  ['s185', 'Capomulin', 'Female', 3, 17, 30, 32.95967078, 1],
#  ['s185', 'Capomulin', 'Female', 3, 17, 35, 28.32853059, 1],
#  ['s185', 'Capomulin', 'Female', 3, 17, 40, 25.47214326, 1],
#  ['s185', 'Capomulin', 'Female', 3, 17, 45, 23.34359787, 1],
#  ['x401', 'Capomulin', 'Female', 16, 15, 0, 45.0, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 5, 45.47375302, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 10, 39.11389068, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 15, 39.77625003, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 20, 36.06583471, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 25, 36.61712031, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 30, 32.91529186, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 35, 30.20682488, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 40, 28.16739732, 0],
#  ['x401', 'Capomulin', 'Female', 16, 15, 45, 28.48403281, 0],
#  ['m601', 'Capomulin', 'Male', 22, 17, 0, 45.0, 0],
#  ['m601', 'Capomulin', 'Male', 22, 17, 5, 41.40859145, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 10, 36.82536664, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 15, 35.46461175, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 20, 34.2557317, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 25, 33.11875607, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 30, 31.75827491, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 35, 30.83435704, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 40, 31.3780453, 1],
#  ['m601', 'Capomulin', 'Male', 22, 17, 45, 28.43096411, 1],
#  ['g791', 'Ramicane', 'Male', 11, 16, 0, 45.0, 0],
#  ['g791', 'Ramicane', 'Male', 11, 16, 5, 45.85153062, 0],
#  ['g791', 'Ramicane', 'Male', 11, 16, 10, 40.17055848, 0],
#  ['g791', 'Ramicane', 'Male', 11, 16, 15, 40.67812852, 0],
#  ['g791', 'Ramicane', 'Male', 11, 16, 20, 41.211897, 0],
#  ['g791', 'Ramicane', 'Male', 11, 16, 25, 35.56939935, 1],
#  ['g791', 'Ramicane', 'Male', 11, 16, 30, 34.95258284, 1],
#  ['g791', 'Ramicane', 'Male', 11, 16, 35, 30.96039194, 1],
#  ['g791', 'Ramicane', 'Male', 11, 16, 40, 31.36940573, 1],
#  ['g791', 'Ramicane', 'Male', 11, 16, 45, 29.12847181, 1],
#  ['s508', 'Ramicane', 'Male', 1, 17, 0, 45.0, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 5, 38.71187185, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 10, 34.8509979, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 15, 35.27690634, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 20, 35.92865083, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 25, 36.33856894, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 30, 35.47402235, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 35, 35.8461407, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 40, 32.79817119, 0],
#  ['s508', 'Ramicane', 'Male', 1, 17, 45, 30.27623175, 0],
#  ['f966', 'Capomulin', 'Male', 16, 17, 0, 45.0, 0],
#  ['f966', 'Capomulin', 'Male', 16, 17, 5, 38.79647373, 0],
#  ['f966', 'Capomulin', 'Male', 16, 17, 10, 35.6244027, 0],
#  ['f966', 'Capomulin', 'Male', 16, 17, 15, 32.62300253, 0],
#  ['f966', 'Capomulin', 'Male', 16, 17, 20, 30.48598484, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 0, 45.0, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 5, 42.99887638, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 10, 43.74822357, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 15, 39.89743533, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 20, 36.71229535, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 25, 37.44444543, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 30, 37.96993365, 0],
#  ['m546', 'Ramicane', 'Male', 18, 16, 35, 38.62753581, 1],
#  ['m546', 'Ramicane', 'Male', 18, 16, 40, 35.1145752, 1],
#  ['m546', 'Ramicane', 'Male', 18, 16, 45, 30.56462509, 1],
#  ['z578', 'Ramicane', 'Male', 11, 16, 0, 45.0, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 5, 42.18878662, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 10, 42.95211843, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 15, 38.68851607, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 20, 36.89001635, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 25, 37.41411419, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 30, 37.81593487, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 35, 38.50482444, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 40, 34.02209336, 0],
#  ['z578', 'Ramicane', 'Male', 11, 16, 45, 30.63869575, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 0, 45.0, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 5, 44.01490022, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 10, 44.49716216, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 15, 45.25253427, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 20, 42.16834132, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 25, 37.86066936, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 30, 34.75724046, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 35, 35.17014843, 0],
#  ['j913', 'Ramicane', 'Female', 4, 17, 40, 31.00186078, 1],
#  ['j913', 'Ramicane', 'Female', 4, 17, 45, 31.56046955, 1],
#  ['u364', 'Capomulin', 'Male', 18, 17, 0, 45.0, 0],
#  ['u364', 'Capomulin', 'Male', 18, 17, 5, 45.76088647, 1],
#  ['u364', 'Capomulin', 'Male', 18, 17, 10, 46.56841719, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 15, 47.21219992, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 20, 40.34394812, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 25, 35.50361557, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 30, 35.9783344, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 35, 35.45948978, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 40, 36.02413752, 2],
#  ['u364', 'Capomulin', 'Male', 18, 17, 45, 31.02392294, 3],
#  ['n364', 'Ramicane', 'Male', 4, 17, 0, 45.0, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 5, 45.52187471, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 10, 40.3751382, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 15, 36.94027399, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 20, 37.4788685, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 25, 33.20500824, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 30, 33.817758, 0],
#  ['n364', 'Ramicane', 'Male', 4, 17, 35, 34.48752204, 1],
#  ['n364', 'Ramicane', 'Male', 4, 17, 40, 34.95473311, 1],
#  ['n364', 'Ramicane', 'Male', 4, 17, 45, 31.09533505, 1],
#  ['y793', 'Capomulin', 'Male', 17, 17, 0, 45.0, 0],
#  ['y793', 'Capomulin', 'Male', 17, 17, 5, 41.01991315, 0],
#  ['y793', 'Capomulin', 'Male', 17, 17, 10, 41.63001026, 1],
#  ['y793', 'Capomulin', 'Male', 17, 17, 15, 42.28366512, 1],
#  ['y793', 'Capomulin', 'Male', 17, 17, 20, 40.71642815, 2],
#  ['y793', 'Capomulin', 'Male', 17, 17, 25, 38.9927339, 2],
#  ['y793', 'Capomulin', 'Male', 17, 17, 30, 35.72602314, 2],
#  ['y793', 'Capomulin', 'Male', 17, 17, 35, 36.3278696, 2],
#  ['y793', 'Capomulin', 'Male', 17, 17, 40, 31.47541076, 2],
#  ['y793', 'Capomulin', 'Male', 17, 17, 45, 31.8962384, 2],
#  ['r554', 'Capomulin', 'Female', 8, 17, 0, 45.0, 0],
#  ['r554', 'Capomulin', 'Female', 8, 17, 5, 45.78174579, 1],
#  ['r554', 'Capomulin', 'Female', 8, 17, 10, 39.0054935, 2],
#  ['r554', 'Capomulin', 'Female', 8, 17, 15, 35.46375763, 2],
#  ['r554', 'Capomulin', 'Female', 8, 17, 20, 36.01558858, 2],
#  ['r554', 'Capomulin', 'Female', 8, 17, 25, 33.89334515, 3],
#  ['r554', 'Capomulin', 'Female', 8, 17, 30, 32.68065459, 3],
#  ['r554', 'Capomulin', 'Female', 8, 17, 35, 33.06933705, 3],
#  ['r554', 'Capomulin', 'Female', 8, 17, 40, 31.80484133, 3],
#  ['r554', 'Capomulin', 'Female', 8, 17, 45, 32.37735684, 3],
#  ['m957', 'Capomulin', 'Female', 3, 19, 0, 45.0, 0],
#  ['m957', 'Capomulin', 'Female', 3, 19, 5, 45.62238149, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 10, 46.4145177, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 15, 39.80445341, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 20, 38.90934919, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 25, 37.69543154, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 30, 38.21247939, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 35, 32.56283914, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 40, 32.94761484, 1],
#  ['m957', 'Capomulin', 'Female', 3, 19, 45, 33.32909778, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 0, 45.0, 0],
#  ['c758', 'Ramicane', 'Male', 9, 17, 5, 45.5786783, 0],
#  ['c758', 'Ramicane', 'Male', 9, 17, 10, 46.28799223, 0],
#  ['c758', 'Ramicane', 'Male', 9, 17, 15, 46.94094512, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 20, 43.1263114, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 25, 43.6022673, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 30, 44.11827028, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 35, 37.80238546, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 40, 32.83318858, 1],
#  ['c758', 'Ramicane', 'Male', 9, 17, 45, 33.39765251, 1],
#  ['t565', 'Capomulin', 'Female', 20, 17, 0, 45.0, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 5, 45.8956472, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 10, 46.74900552, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 15, 44.44094861, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 20, 39.0702138, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 25, 37.34220976, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 30, 32.86891617, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 35, 33.51567063, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 40, 33.94934131, 0],
#  ['t565', 'Capomulin', 'Female', 20, 17, 45, 34.45529799, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 0, 45.0, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 5, 45.55015754, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 10, 46.38071258, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 15, 46.91089166, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 20, 45.86506461, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 25, 41.48122408, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 30, 37.21112063, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 35, 35.12863083, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 40, 35.77945086, 0],
#  ['a644', 'Ramicane', 'Female', 7, 17, 45, 32.97852192, 1],
#  ['i177', 'Ramicane', 'Male', 10, 18, 0, 45.0, 0],
#  ['i177', 'Ramicane', 'Male', 10, 18, 5, 44.06539783, 0],
#  ['i177', 'Ramicane', 'Male', 10, 18, 10, 41.02092924, 0],
#  ['i177', 'Ramicane', 'Male', 10, 18, 15, 40.33093479, 0],
#  ['i177', 'Ramicane', 'Male', 10, 18, 20, 35.34536136, 0],
#  ['i177', 'Ramicane', 'Male', 10, 18, 25, 34.0821803, 1],
#  ['i177', 'Ramicane', 'Male', 10, 18, 30, 34.71147302, 1],
#  ['i177', 'Ramicane', 'Male', 10, 18, 35, 35.1521662, 1],
#  ['i177', 'Ramicane', 'Male', 10, 18, 40, 35.55793279, 2],
#  ['i177', 'Ramicane', 'Male', 10, 18, 45, 33.56240217, 3],
#  ['j989', 'Ramicane', 'Male', 8, 19, 0, 45.0, 0],
#  ['j989', 'Ramicane', 'Male', 8, 19, 5, 45.62071835, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 10, 46.34383237, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 15, 41.12835439, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 20, 41.63534426, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 25, 39.93411249, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 30, 34.67178107, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 35, 35.1155898, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 40, 35.50119014, 1],
#  ['j989', 'Ramicane', 'Male', 8, 19, 45, 36.13485243, 1],
#  ['i738', 'Capomulin', 'Female', 23, 20, 0, 45.0, 0],
#  ['i738', 'Capomulin', 'Female', 23, 20, 5, 45.59568527, 0],
#  ['i738', 'Capomulin', 'Female', 23, 20, 10, 43.42101414, 0],
#  ['i738', 'Capomulin', 'Female', 23, 20, 15, 37.97877782, 0],
#  ['i738', 'Capomulin', 'Female', 23, 20, 20, 38.53113634, 0],
#  ['i738', 'Capomulin', 'Female', 23, 20, 25, 34.97343761, 0],
#  ['i738', 'Capomulin', 'Female', 23, 20, 30, 35.57877987, 1],
#  ['i738', 'Capomulin', 'Female', 23, 20, 35, 36.17595269, 1],
#  ['i738', 'Capomulin', 'Female', 23, 20, 40, 36.84389799, 2],
#  ['i738', 'Capomulin', 'Female', 23, 20, 45, 37.31184577, 2],
#  ['a520', 'Ramicane', 'Male', 13, 21, 0, 45.0, 0],
#  ['a520', 'Ramicane', 'Male', 13, 21, 5, 38.72370695, 0],
#  ['a520', 'Ramicane', 'Male', 13, 21, 10, 36.42938781, 0],
#  ['a520', 'Ramicane', 'Male', 13, 21, 15, 35.590254, 0],
#  ['a520', 'Ramicane', 'Male', 13, 21, 20, 35.94774514, 0],
#  ['a520', 'Ramicane', 'Male', 13, 21, 25, 36.55858129, 1],
#  ['a520', 'Ramicane', 'Male', 13, 21, 30, 36.94770981, 1],
#  ['a520', 'Ramicane', 'Male', 13, 21, 35, 37.62471026, 1],
#  ['a520', 'Ramicane', 'Male', 13, 21, 40, 38.25972497, 1],
#  ['a520', 'Ramicane', 'Male', 13, 21, 45, 38.81036633, 1],
#  ['w914', 'Capomulin', 'Male', 24, 21, 0, 45.0, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 5, 45.89372032, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 10, 43.23196275, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 15, 43.68844893, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 20, 41.10809233, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 25, 40.29191661, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 30, 40.99311013, 0],
#  ['w914', 'Capomulin', 'Male', 24, 21, 35, 41.66491577, 1],
#  ['w914', 'Capomulin', 'Male', 24, 21, 40, 35.61130861, 2],
#  ['w914', 'Capomulin', 'Male', 24, 21, 45, 36.04104736, 2],
#  ['r811', 'Ramicane', 'Male', 9, 19, 0, 45.0, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 5, 45.62580225, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 10, 39.453903, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 15, 40.02229235, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 20, 40.7728027, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 25, 37.61401068, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 30, 38.24206639, 0],
#  ['r811', 'Ramicane', 'Male', 9, 19, 35, 36.00302016, 1],
#  ['r811', 'Ramicane', 'Male', 9, 19, 40, 36.5200329, 1],
#  ['r811', 'Ramicane', 'Male', 9, 19, 45, 37.22565033, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 0, 45.0, 0],
#  ['g288', 'Capomulin', 'Male', 3, 19, 5, 45.83939976, 0],
#  ['g288', 'Capomulin', 'Male', 3, 19, 10, 46.30400254, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 15, 42.17230079, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 20, 42.95712001, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 25, 42.36869239, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 30, 42.87446056, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 35, 38.95411458, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 40, 36.35685121, 1],
#  ['g288', 'Capomulin', 'Male', 3, 19, 45, 37.07402422, 1],
#  ['i334', 'Ramicane', 'Female', 8, 20, 0, 45.0, 0],
#  ['i334', 'Ramicane', 'Female', 8, 20, 5, 41.02051821, 0],
#  ['i334', 'Ramicane', 'Female', 8, 20, 10, 41.63124731, 0],
#  ['i334', 'Ramicane', 'Female', 8, 20, 15, 39.15800115, 0],
#  ['i334', 'Ramicane', 'Female', 8, 20, 20, 39.6878317, 0],
#  ['i334', 'Ramicane', 'Female', 8, 20, 25, 38.24881732, 1],
#  ['i334', 'Ramicane', 'Female', 8, 20, 30, 39.00555435, 1],
#  ['i334', 'Ramicane', 'Female', 8, 20, 35, 39.7695521, 2],
#  ['i334', 'Ramicane', 'Female', 8, 20, 40, 40.44237037, 2],
#  ['i334', 'Ramicane', 'Female', 8, 20, 45, 36.37451039, 2],
#  ['q610', 'Ramicane', 'Female', 18, 21, 0, 45.0, 0],
#  ['q610', 'Ramicane', 'Female', 18, 21, 5, 45.62949421, 0],
#  ['q610', 'Ramicane', 'Female', 18, 21, 10, 44.99148471, 0],
#  ['q610', 'Ramicane', 'Female', 18, 21, 15, 45.88902756, 0],
#  ['q610', 'Ramicane', 'Female', 18, 21, 20, 46.58543347, 0],
#  ['q610', 'Ramicane', 'Female', 18, 21, 25, 40.14645019, 0],
#  ['q610', 'Ramicane', 'Female', 18, 21, 30, 40.66834256, 1],
#  ['q610', 'Ramicane', 'Female', 18, 21, 35, 36.56165229, 2],
#  ['d251', 'Ramicane', 'Female', 8, 19, 0, 45.0, 0],
#  ['d251', 'Ramicane', 'Female', 8, 19, 5, 41.74635495, 1],
#  ['d251', 'Ramicane', 'Female', 8, 19, 10, 42.43225791, 1],
#  ['d251', 'Ramicane', 'Female', 8, 19, 15, 39.47278744, 1],
#  ['d251', 'Ramicane', 'Female', 8, 19, 20, 37.65209085, 1],
#  ['d251', 'Ramicane', 'Female', 8, 19, 25, 38.09751328, 1],
#  ['d251', 'Ramicane', 'Female', 8, 19, 30, 38.71825638, 2],
#  ['d251', 'Ramicane', 'Female', 8, 19, 35, 37.70852942, 2],
#  ['d251', 'Ramicane', 'Female', 8, 19, 40, 38.26540379, 2],
#  ['d251', 'Ramicane', 'Female', 8, 19, 45, 37.31123552, 2],
#  ['l897', 'Capomulin', 'Male', 17, 19, 0, 45.0, 0],
#  ['l897', 'Capomulin', 'Male', 17, 19, 5, 45.46224327, 0],
#  ['l897', 'Capomulin', 'Male', 17, 19, 10, 46.15473721, 0],
#  ['l897', 'Capomulin', 'Male', 17, 19, 15, 44.0615214, 0],
#  ['l897', 'Capomulin', 'Male', 17, 19, 20, 44.81309343, 0],
#  ['l897', 'Capomulin', 'Male', 17, 19, 25, 45.35467916, 0],
#  ['l897', 'Capomulin', 'Male', 17, 19, 30, 39.35279201, 1],
#  ['l897', 'Capomulin', 'Male', 17, 19, 35, 37.68276664, 1],
#  ['l897', 'Capomulin', 'Male', 17, 19, 40, 38.34390154, 1],
#  ['l897', 'Capomulin', 'Male', 17, 19, 45, 38.84687569, 1],
#  ['c458', 'Ramicane', 'Female', 23, 20, 0, 45.0, 0],
#  ['c458', 'Ramicane', 'Female', 23, 20, 5, 45.72227949, 0],
#  ['c458', 'Ramicane', 'Female', 23, 20, 10, 44.45437828, 1],
#  ['c458', 'Ramicane', 'Female', 23, 20, 15, 45.10742313, 2],
#  ['c458', 'Ramicane', 'Female', 23, 20, 20, 39.50513508, 2],
#  ['c458', 'Ramicane', 'Female', 23, 20, 25, 37.75314964, 2],
#  ['c458', 'Ramicane', 'Female', 23, 20, 30, 38.34200823, 2],
#  ['b742', 'Capomulin', 'Male', 7, 21, 0, 45.0, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 5, 41.53409702, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 10, 41.99922813, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 15, 39.52484301, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 20, 37.95035546, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 25, 38.61768433, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 30, 39.1679495, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 35, 39.84757556, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 40, 38.2556274, 0],
#  ['b742', 'Capomulin', 'Male', 7, 21, 45, 38.93963263, 0],
#  ['b128', 'Capomulin', 'Female', 9, 22, 0, 45.0, 0],
#  ['b128', 'Capomulin', 'Female', 9, 22, 5, 45.65133131, 0],
#  ['b128', 'Capomulin', 'Female', 9, 22, 10, 43.2708519, 0],
#  ['b128', 'Capomulin', 'Female', 9, 22, 15, 43.78489343, 0],
#  ['b128', 'Capomulin', 'Female', 9, 22, 20, 42.731552, 0],
#  ['b128', 'Capomulin', 'Female', 9, 22, 25, 43.26214483, 1],
#  ['b128', 'Capomulin', 'Female', 9, 22, 30, 40.60533486, 1],
#  ['b128', 'Capomulin', 'Female', 9, 22, 35, 37.96764437, 1],
#  ['b128', 'Capomulin', 'Female', 9, 22, 40, 38.3797259, 2],
#  ['b128', 'Capomulin', 'Female', 9, 22, 45, 38.98287774, 2],
#  ['j246', 'Capomulin', 'Female', 21, 21, 0, 45.0, 0],
#  ['j246', 'Capomulin', 'Female', 21, 21, 5, 45.64143788, 0],
#  ['j246', 'Capomulin', 'Female', 21, 21, 10, 46.4083613, 0],
#  ['j246', 'Capomulin', 'Female', 21, 21, 15, 43.31265415, 0],
#  ['j246', 'Capomulin', 'Female', 21, 21, 20, 44.02037009, 0],
#  ['j246', 'Capomulin', 'Female', 21, 21, 25, 44.55522595, 0],
#  ['j246', 'Capomulin', 'Female', 21, 21, 30, 38.04408202, 1],
#  ['j246', 'Capomulin', 'Female', 21, 21, 35, 38.75326548, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 0, 45.0, 0],
#  ['a411', 'Ramicane', 'Male', 3, 22, 5, 45.46667714, 0],
#  ['a411', 'Ramicane', 'Male', 3, 22, 10, 40.75978762, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 15, 41.48416885, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 20, 38.08737318, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 25, 38.7014384, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 30, 39.13073724, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 35, 39.71723589, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 40, 40.25881765, 1],
#  ['a411', 'Ramicane', 'Male', 3, 22, 45, 38.4076183, 1],
#  ['j119', 'Capomulin', 'Female', 7, 23, 0, 45.0, 0],
#  ['j119', 'Capomulin', 'Female', 7, 23, 5, 45.83899787, 0],
#  ['j119', 'Capomulin', 'Female', 7, 23, 10, 46.42536551, 0],
#  ['j119', 'Capomulin', 'Female', 7, 23, 15, 47.32298428, 0],
#  ['j119', 'Capomulin', 'Female', 7, 23, 20, 48.15820939, 1],
#  ['j119', 'Capomulin', 'Female', 7, 23, 25, 42.41716589, 1],
#  ['j119', 'Capomulin', 'Female', 7, 23, 30, 43.01368114, 1],
#  ['j119', 'Capomulin', 'Female', 7, 23, 35, 43.76570537, 1],
#  ['j119', 'Capomulin', 'Female', 7, 23, 40, 44.5850896, 1],
#  ['j119', 'Capomulin', 'Female', 7, 23, 45, 38.1251644, 1],
#  ['w150', 'Capomulin', 'Male', 23, 23, 0, 45.0, 0],
#  ['w150', 'Capomulin', 'Male', 23, 23, 5, 39.20212894, 0],
#  ['w150', 'Capomulin', 'Male', 23, 23, 10, 39.95234669, 0],
#  ['v923', 'Capomulin', 'Female', 19, 21, 0, 45.0, 0],
#  ['v923', 'Capomulin', 'Female', 19, 21, 5, 45.70443431, 0],
#  ['v923', 'Capomulin', 'Female', 19, 21, 10, 39.84822328, 0],
#  ['v923', 'Capomulin', 'Female', 19, 21, 15, 40.45798877, 0],
#  ['v923', 'Capomulin', 'Female', 19, 21, 20, 39.64829568, 0],
#  ['v923', 'Capomulin', 'Female', 19, 21, 25, 40.15641269, 1],
#  ['v923', 'Capomulin', 'Female', 19, 21, 30, 40.75221626, 2],
#  ['v923', 'Capomulin', 'Female', 19, 21, 35, 41.43924156, 2],
#  ['v923', 'Capomulin', 'Female', 19, 21, 40, 42.1510148, 2],
#  ['v923', 'Capomulin', 'Female', 19, 21, 45, 40.65812366, 2],
#  ['g316', 'Capomulin', 'Female', 22, 22, 0, 45.0, 0],
#  ['g316', 'Capomulin', 'Female', 22, 22, 5, 44.02275246, 0],
#  ['g316', 'Capomulin', 'Female', 22, 22, 10, 44.50204246, 0],
#  ['g316', 'Capomulin', 'Female', 22, 22, 15, 45.21674299, 0],
#  ['g316', 'Capomulin', 'Female', 22, 22, 20, 45.93332219, 1],
#  ['g316', 'Capomulin', 'Female', 22, 22, 25, 46.80922469, 1],
#  ['g316', 'Capomulin', 'Female', 22, 22, 30, 44.22147988, 2],
#  ['g316', 'Capomulin', 'Female', 22, 22, 35, 44.70283296, 2],
#  ['g316', 'Capomulin', 'Female', 22, 22, 40, 45.56582103, 2],
#  ['g316', 'Capomulin', 'Female', 22, 22, 45, 40.1592203, 2],
#  ['s710', 'Capomulin', 'Female', 1, 23, 0, 45.0, 0],
#  ['s710', 'Capomulin', 'Female', 1, 23, 5, 43.1809774, 0],
#  ['s710', 'Capomulin', 'Female', 1, 23, 10, 43.68802627, 0],
#  ['s710', 'Capomulin', 'Female', 1, 23, 15, 41.84523536, 0],
#  ['s710', 'Capomulin', 'Female', 1, 23, 20, 42.62996266, 1],
#  ['s710', 'Capomulin', 'Female', 1, 23, 25, 43.06040875, 1],
#  ['s710', 'Capomulin', 'Female', 1, 23, 30, 43.57170323, 1],
#  ['s710', 'Capomulin', 'Female', 1, 23, 35, 44.16051879, 1],
#  ['s710', 'Capomulin', 'Female', 1, 23, 40, 40.17192011, 1],
#  ['s710', 'Capomulin', 'Female', 1, 23, 45, 40.72857787, 1],
#  ['l509', 'Capomulin', 'Male', 17, 21, 0, 45.0, 0],
#  ['l509', 'Capomulin', 'Male', 17, 21, 5, 45.85119285, 0],
#  ['l509', 'Capomulin', 'Male', 17, 21, 10, 46.75907363, 0],
#  ['l509', 'Capomulin', 'Male', 17, 21, 15, 47.48859931, 1],
#  ['l509', 'Capomulin', 'Male', 17, 21, 20, 48.07045162, 2],
#  ['l509', 'Capomulin', 'Male', 17, 21, 25, 44.00625702, 2],
#  ['l509', 'Capomulin', 'Male', 17, 21, 30, 44.70805473, 2],
#  ['l509', 'Capomulin', 'Male', 17, 21, 35, 40.2072885, 2],
#  ['l509', 'Capomulin', 'Male', 17, 21, 40, 40.77081259, 2],
#  ['l509', 'Capomulin', 'Male', 17, 21, 45, 41.48300765, 3],
#  ['r944', 'Capomulin', 'Male', 12, 25, 0, 45.0, 0],
#  ['r944', 'Capomulin', 'Male', 12, 25, 5, 45.73714484, 0],
#  ['r944', 'Capomulin', 'Male', 12, 25, 10, 46.54429202, 0],
#  ['r944', 'Capomulin', 'Male', 12, 25, 15, 47.37342325, 0],
#  ['r944', 'Capomulin', 'Male', 12, 25, 20, 43.22567119, 1],
#  ['r944', 'Capomulin', 'Male', 12, 25, 25, 41.08699106, 1],
#  ['r944', 'Capomulin', 'Male', 12, 25, 30, 41.68079111, 1],
#  ['r944', 'Capomulin', 'Male', 12, 25, 35, 40.40176542, 2],
#  ['r944', 'Capomulin', 'Male', 12, 25, 40, 41.0420449, 2],
#  ['r944', 'Capomulin', 'Male', 12, 25, 45, 41.58152074, 2],
#  ['e662', 'Ramicane', 'Male', 8, 24, 0, 45.0, 0],
#  ['e662', 'Ramicane', 'Male', 8, 24, 5, 45.81628252, 0],
#  ['e662', 'Ramicane', 'Male', 8, 24, 10, 46.40908385, 0],
#  ['e662', 'Ramicane', 'Male', 8, 24, 15, 43.55377339, 0],
#  ['e662', 'Ramicane', 'Male', 8, 24, 20, 44.0012958, 0],
#  ['e662', 'Ramicane', 'Male', 8, 24, 25, 44.66459432, 1],
#  ['e662', 'Ramicane', 'Male', 8, 24, 30, 45.35023242, 1],
#  ['e662', 'Ramicane', 'Male', 8, 24, 35, 43.22027636, 1],
#  ['e662', 'Ramicane', 'Male', 8, 24, 40, 44.00672385, 2],
#  ['e662', 'Ramicane', 'Male', 8, 24, 45, 40.65900627, 2],
#  ['u196', 'Ramicane', 'Male', 18, 25, 0, 45.0, 0],
#  ['u196', 'Ramicane', 'Male', 18, 25, 5, 45.55746444, 1],
#  ['u196', 'Ramicane', 'Male', 18, 25, 10, 46.42294306, 1],
#  ['u196', 'Ramicane', 'Male', 18, 25, 15, 47.22717065, 1],
#  ['u196', 'Ramicane', 'Male', 18, 25, 20, 46.10536303, 1],
#  ['u196', 'Ramicane', 'Male', 18, 25, 25, 46.7053254, 1],
#  ['u196', 'Ramicane', 'Male', 18, 25, 30, 47.62281636, 2],
#  ['u196', 'Ramicane', 'Male', 18, 25, 35, 47.00146542, 2],
#  ['u196', 'Ramicane', 'Male', 18, 25, 40, 43.45368679, 2],
#  ['u196', 'Ramicane', 'Male', 18, 25, 45, 40.66771292, 3],
#  ['q597', 'Ramicane', 'Male', 20, 25, 0, 45.0, 0],
#  ['q597', 'Ramicane', 'Male', 20, 25, 5, 45.76611104, 0],
#  ['q597', 'Ramicane', 'Male', 20, 25, 10, 42.53798598, 0],
#  ['q597', 'Ramicane', 'Male', 20, 25, 15, 41.39566036, 0],
#  ['q597', 'Ramicane', 'Male', 20, 25, 20, 41.9255866, 0],
#  ['q597', 'Ramicane', 'Male', 20, 25, 25, 42.57570709, 1],
#  ['q597', 'Ramicane', 'Male', 20, 25, 30, 43.33916123, 1],
#  ['q597', 'Ramicane', 'Male', 20, 25, 35, 43.80720142, 1],
#  ['q597', 'Ramicane', 'Male', 20, 25, 40, 44.47182121, 2],
#  ['q597', 'Ramicane', 'Male', 20, 25, 45, 45.22086888, 2],
#  ['a444', 'Ramicane', 'Female', 10, 25, 0, 45.0, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 5, 44.00597487, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 10, 44.51255951, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 15, 43.00127957, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 20, 41.71461874, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 25, 42.29139437, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 30, 42.78627835, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 35, 41.73595083, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 40, 42.50492554, 0],
#  ['a444', 'Ramicane', 'Female', 10, 25, 45, 43.0475426, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 0, 45.0, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 5, 42.2616653, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 10, 42.99207658, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 15, 43.5298757, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 20, 43.96789516, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 25, 44.59621854, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 30, 45.26138381, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 35, 45.94194901, 0],
#  ['i557', 'Capomulin', 'Female', 1, 24, 40, 46.82106972, 1],
#  ['i557', 'Capomulin', 'Female', 1, 24, 45, 47.68596303, 1],
#  ['r921', 'Ramicane', 'Female', 5, 25, 0, 45.0, 0],
#  ['r921', 'Ramicane', 'Female', 5, 25, 5, 45.56821083, 0],
#  ['r921', 'Ramicane', 'Female', 5, 25, 10, 42.71192694, 0],
#  ['r921', 'Ramicane', 'Female', 5, 25, 15, 43.52726054, 0],
#  ['r921', 'Ramicane', 'Female', 5, 25, 20, 44.13631588, 0],
#  ['r921', 'Ramicane', 'Female', 5, 25, 25, 42.65534089, 1],
#  ['r921', 'Ramicane', 'Female', 5, 25, 30, 43.41938077, 1],
#  ['w678', 'Ramicane', 'Female', 5, 24, 0, 45.0, 0],
#  ['w678', 'Ramicane', 'Female', 5, 24, 5, 43.16637266, 0],
#  ['y449', 'Ramicane', 'Male', 19, 24, 0, 45.0, 0],
#  ['y449', 'Ramicane', 'Male', 19, 24, 5, 45.87754494, 0],
#  ['y449', 'Ramicane', 'Male', 19, 24, 10, 46.37809248, 0],
#  ['y449', 'Ramicane', 'Male', 19, 24, 15, 44.18345092, 0],
#  ['a203', 'Infubinol', 'Female', 20, 23, 0, 45.0, 0],
#  ['a203', 'Infubinol', 'Female', 20, 23, 5, 48.5084684, 0],
#  ['a203', 'Infubinol', 'Female', 20, 23, 10, 51.8524372, 1],
#  ['a203', 'Infubinol', 'Female', 20, 23, 15, 52.7778705, 1],
#  ['a203', 'Infubinol', 'Female', 20, 23, 20, 55.17333648, 1],
#  ['a203', 'Infubinol', 'Female', 20, 23, 25, 56.79320832, 1],
#  ['a203', 'Infubinol', 'Female', 20, 23, 30, 59.52319728, 1],
#  ['a203', 'Infubinol', 'Female', 20, 23, 35, 61.93165007, 2],
#  ['a203', 'Infubinol', 'Female', 20, 23, 40, 63.59349002, 2],
#  ['a203', 'Infubinol', 'Female', 20, 23, 45, 67.97341878, 2],
#  ['a251', 'Infubinol', 'Female', 21, 25, 0, 45.0, 0],
#  ['a251', 'Infubinol', 'Female', 21, 25, 5, 46.98212719, 0],
#  ['a251', 'Infubinol', 'Female', 21, 25, 10, 48.59117901, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 15, 50.53445603, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 20, 54.46259376, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 25, 57.4146457, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 30, 59.86124129, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 35, 60.90388455, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 40, 63.09507565, 1],
#  ['a251', 'Infubinol', 'Female', 21, 25, 45, 65.52574285, 1],
#  ['a262', 'Placebo', 'Female', 17, 29, 0, 45.0, 0],
#  ['a262', 'Placebo', 'Female', 17, 29, 5, 48.71756819, 1],
#  ['a262', 'Placebo', 'Female', 17, 29, 10, 49.59518129, 1],
#  ['a262', 'Placebo', 'Female', 17, 29, 15, 53.82797367, 2],
#  ['a262', 'Placebo', 'Female', 17, 29, 20, 57.01331331, 2],
#  ['a262', 'Placebo', 'Female', 17, 29, 25, 60.13186217, 2],
#  ['a262', 'Placebo', 'Female', 17, 29, 30, 64.95809178, 3],
#  ['a262', 'Placebo', 'Female', 17, 29, 35, 66.56196302, 4],
#  ['a262', 'Placebo', 'Female', 17, 29, 40, 69.59273198, 4],
#  ['a262', 'Placebo', 'Female', 17, 29, 45, 70.71762058, 4],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 0, 45.0, 0],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 5, 46.79525728, 0],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 10, 47.37134328, 0],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 15, 49.73440359, 0],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 20, 50.51343652, 1],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 25, 53.57606417, 1],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 30, 54.44471317, 2],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 35, 56.35353804, 2],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 40, 60.92153868, 3],
#  ['a275', 'Ceftamin', 'Female', 20, 28, 45, 62.99935619, 3],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 0, 45.0, 0],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 5, 48.95136773, 0],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 10, 53.52399007, 0],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 15, 55.26558163, 0],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 20, 57.28598742, 0],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 25, 59.01172817, 0],
#  ['a366', 'Stelasyn', 'Female', 16, 29, 30, 63.44068627, 1],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 0, 45.0, 0],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 5, 46.11198591, 0],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 10, 47.7259374, 1],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 15, 49.93472542, 1],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 20, 52.20451136, 2],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 25, 54.20983551, 3],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 30, 55.91016159, 3],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 35, 60.34714467, 3],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 40, 61.76860538, 4],
#  ['a401', 'Zoniferol', 'Female', 8, 25, 45, 66.79415599, 4],
#  ['a457', 'Ketapril', 'Female', 11, 30, 0, 45.0, 0],
#  ['a457', 'Ketapril', 'Female', 11, 30, 5, 47.462891, 0],
#  ['a457', 'Ketapril', 'Female', 11, 30, 10, 49.78341894, 0],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 0, 45.0, 0],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 5, 46.40914339, 0],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 10, 48.43219661, 0],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 15, 51.9852629, 0],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 20, 53.67719253, 0],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 25, 54.70122868, 1],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 30, 56.20104104, 1],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 35, 57.30855379, 1],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 40, 57.92849897, 1],
#  ['a492', 'Stelasyn', 'Male', 20, 25, 45, 60.12201052, 1],
#  ['a577', 'Infubinol', 'Female', 6, 25, 0, 45.0, 0],
#  ['a577', 'Infubinol', 'Female', 6, 25, 5, 46.1977199, 1],
#  ['a577', 'Infubinol', 'Female', 6, 25, 10, 49.5096389, 1],
#  ['a577', 'Infubinol', 'Female', 6, 25, 15, 50.91500662, 2],
#  ['a577', 'Infubinol', 'Female', 6, 25, 20, 52.36518457, 2],
#  ['a577', 'Infubinol', 'Female', 6, 25, 25, 54.38093154, 2],
#  ['a577', 'Infubinol', 'Female', 6, 25, 30, 57.03186187, 2],
#  ['a685', 'Infubinol', 'Male', 8, 30, 0, 45.0, 0],
#  ['a685', 'Infubinol', 'Male', 8, 30, 5, 46.87048256, 0],
#  ['a685', 'Infubinol', 'Male', 8, 30, 10, 47.66475264, 0],
#  ['a685', 'Infubinol', 'Male', 8, 30, 15, 48.95147442, 0],
#  ['a685', 'Infubinol', 'Male', 8, 30, 20, 49.49055902, 0],
#  ['a685', 'Infubinol', 'Male', 8, 30, 25, 51.93995092, 0],
#  ['a685', 'Infubinol', 'Male', 8, 30, 30, 55.45385519, 1],
#  ['a685', 'Infubinol', 'Male', 8, 30, 35, 58.09262925, 1],
#  ['a685', 'Infubinol', 'Male', 8, 30, 40, 60.56790371, 2],
#  ['a685', 'Infubinol', 'Male', 8, 30, 45, 66.08306589, 3],
#  ['a699', 'Propriva', 'Female', 5, 28, 0, 45.0, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 5, 46.55308986, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 10, 47.86737569, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 15, 49.53040137, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 20, 50.71242334, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 25, 51.84638147, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 30, 54.37934505, 0],
#  ['a699', 'Propriva', 'Female', 5, 28, 35, 56.51068234, 1],
#  ['a699', 'Propriva', 'Female', 5, 28, 40, 58.60544816, 1],
#  ['a699', 'Propriva', 'Female', 5, 28, 45, 62.19141437, 1],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 0, 45.0, 0],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 5, 47.00658024, 0],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 10, 50.15972132, 1],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 15, 52.53994926, 1],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 20, 54.06098332, 1],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 25, 56.7702803, 1],
#  ['a788', 'Zoniferol', 'Male', 5, 30, 30, 60.41370908, 1],
#  ['a818', 'Naftisol', 'Female', 12, 28, 0, 45.0, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 5, 45.69670864, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 10, 49.79091948, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 15, 51.22756565, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 20, 54.8346245, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 25, 56.96627332, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 30, 60.07237198, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 35, 63.29854586, 0],
#  ['a818', 'Naftisol', 'Female', 12, 28, 40, 69.27381374, 1],
#  ['a818', 'Naftisol', 'Female', 12, 28, 45, 74.99776443, 2],
#  ['a897', 'Placebo', 'Male', 7, 28, 0, 45.0, 0],
#  ['a897', 'Placebo', 'Male', 7, 28, 5, 45.69112405, 1],
#  ['a897', 'Placebo', 'Male', 7, 28, 10, 47.97292708, 1],
#  ['a897', 'Placebo', 'Male', 7, 28, 15, 52.34308525, 2],
#  ['a897', 'Placebo', 'Male', 7, 28, 20, 54.59570541, 3],
#  ['a897', 'Placebo', 'Male', 7, 28, 25, 56.41331977, 3],
#  ['a897', 'Placebo', 'Male', 7, 28, 30, 59.91693443, 3],
#  ['a897', 'Placebo', 'Male', 7, 28, 35, 64.0528731, 3],
#  ['a897', 'Placebo', 'Male', 7, 28, 40, 67.21174279, 4],
#  ['a897', 'Placebo', 'Male', 7, 28, 45, 72.25596306, 4],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 0, 45.0, 0],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 5, 46.23350581, 0],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 10, 47.15052201, 0],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 15, 47.83685218, 0],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 20, 51.46373448, 0],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 25, 52.12980374, 0],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 30, 53.40166738, 1],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 35, 56.81397646, 1],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 40, 58.46378685, 1],
#  ['a963', 'Stelasyn', 'Female', 23, 27, 45, 62.76509317, 1],
#  ['b313', 'Zoniferol', 'Male', 12, 27, 0, 45.0, 0],
#  ['b313', 'Zoniferol', 'Male', 12, 27, 5, 47.15443254, 0],
#  ['b313', 'Zoniferol', 'Male', 12, 27, 10, 48.31937218, 1],
#  ['b313', 'Zoniferol', 'Male', 12, 27, 15, 49.18838735, 1],
#  ['b313', 'Zoniferol', 'Male', 12, 27, 20, 53.9796797, 1],
#  ['b313', 'Zoniferol', 'Male', 12, 27, 25, 55.74514628, 1],
#  ['b447', 'Ceftamin', 'Male', 2, 30, 0, 45.0, 0],
#  ['b487', 'Ceftamin', 'Female', 6, 28, 0, 45.0, 0],
#  ['b487', 'Ceftamin', 'Female', 6, 28, 5, 46.21397739, 0],
#  ['b487', 'Ceftamin', 'Female', 6, 28, 10, 47.6643871, 0],
#  ['b487', 'Ceftamin', 'Female', 6, 28, 15, 51.68325586, 0],
#  ['b487', 'Ceftamin', 'Female', 6, 28, 20, 53.42766344, 0],
#  ['b487', 'Ceftamin', 'Female', 6, 28, 25, 56.05774909, 1],
#  ['b559', 'Naftisol', 'Male', 20, 26, 0, 45.0, 0],
#  ['b559', 'Naftisol', 'Male', 20, 26, 5, 47.40989731, 0],
#  ['b559', 'Naftisol', 'Male', 20, 26, 10, 48.03643202, 0],
#  ['b559', 'Naftisol', 'Male', 20, 26, 15, 51.37886229, 0],
#  ['b559', 'Naftisol', 'Male', 20, 26, 20, 55.65445572, 1],
#  ['b559', 'Naftisol', 'Male', 20, 26, 25, 57.04366929, 1],
#  ['b559', 'Naftisol', 'Male', 20, 26, 30, 61.19038663, 1],
#  ['b559', 'Naftisol', 'Male', 20, 26, 35, 65.70576275, 1],
#  ['b559', 'Naftisol', 'Male', 20, 26, 40, 69.96961645, 1],
#  ['b559', 'Naftisol', 'Male', 20, 26, 45, 73.05136339, 1],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 0, 45.0, 0],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 5, 48.00919049, 0],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 10, 49.13335499, 0],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 15, 51.58779906, 0],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 20, 54.44303502, 0],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 25, 55.08363235, 0],
#  ['b759', 'Ceftamin', 'Female', 12, 25, 30, 55.74282869, 1],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 0, 45.0, 0],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 5, 49.15615628, 1],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 10, 50.33894583, 1],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 15, 51.61838657, 1],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 20, 53.98343568, 1],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 25, 56.46998744, 2],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 30, 60.90761481, 2],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 35, 64.26088633, 2],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 40, 67.18912666, 2],
#  ['b879', 'Stelasyn', 'Female', 4, 26, 45, 72.55523894, 2],
#  ['c139', 'Infubinol', 'Male', 11, 28, 0, 45.0, 0],
#  ['c139', 'Infubinol', 'Male', 11, 28, 5, 48.75311208, 0],
#  ['c139', 'Infubinol', 'Male', 11, 28, 10, 49.99295391, 0],
#  ['c139', 'Infubinol', 'Male', 11, 28, 15, 51.8332246, 0],
#  ['c139', 'Infubinol', 'Male', 11, 28, 20, 56.74200681, 0],
#  ['c139', 'Infubinol', 'Male', 11, 28, 25, 61.46196976, 0],
#  ['c139', 'Infubinol', 'Male', 11, 28, 30, 64.14987077, 1],
#  ['c139', 'Infubinol', 'Male', 11, 28, 35, 67.82141969, 1],
#  ['c139', 'Infubinol', 'Male', 11, 28, 40, 69.42814095, 2],
#  ['c139', 'Infubinol', 'Male', 11, 28, 45, 72.2267309, 2],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 0, 45.0, 0],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 5, 45.79170389, 0],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 10, 49.02659196, 0],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 15, 53.66494165, 1],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 20, 54.5681957, 1],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 25, 56.96676876, 2],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 30, 57.82391556, 2],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 35, 61.07479506, 2],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 40, 65.70832272, 2],
#  ['c264', 'Zoniferol', 'Female', 11, 27, 45, 67.94212107, 2],
#  ['c282', 'Placebo', 'Male', 12, 27, 0, 45.0, 0],
#  ['c282', 'Placebo', 'Male', 12, 27, 5, 45.72568973, 0],
#  ['c282', 'Placebo', 'Male', 12, 27, 10, 48.17950638, 0],
#  ['c282', 'Placebo', 'Male', 12, 27, 15, 49.26607873, 0],
#  ['c282', 'Placebo', 'Male', 12, 27, 20, 51.95057423, 0],
#  ['c282', 'Placebo', 'Male', 12, 27, 25, 56.29220039, 1],
#  ['c282', 'Placebo', 'Male', 12, 27, 30, 59.00590207, 1],
#  ['c282', 'Placebo', 'Male', 12, 27, 35, 59.88765475, 1],
#  ['c282', 'Placebo', 'Male', 12, 27, 40, 65.02179944, 2],
#  ['c282', 'Placebo', 'Male', 12, 27, 45, 65.81516535, 2],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 0, 45.0, 0],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 5, 47.69067986, 1],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 10, 48.53356704, 1],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 15, 52.71663459, 2],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 20, 54.08090836, 3],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 25, 55.07622853, 3],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 30, 57.41974389, 3],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 35, 62.23657157, 3],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 40, 63.28107148, 4],
#  ['c302', 'Zoniferol', 'Female', 10, 29, 45, 64.57522157, 4],
#  ['c326', 'Infubinol', 'Female', 18, 25, 0, 45.0, 0],
#  ['c326', 'Infubinol', 'Female', 18, 25, 5, 36.3213458, 0],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 0, 45.0, 0],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 5, 49.3426301, 1],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 10, 50.56689412, 1],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 15, 52.23071944, 1],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 20, 54.88332044, 2],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 25, 58.26988853, 2],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 30, 63.74319428, 2],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 35, 65.8079627, 2],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 40, 70.22229679, 2],
#  ['c402', 'Stelasyn', 'Female', 1, 27, 45, 74.04039018, 3],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 0, 45.0, 0],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 5, 46.56263793, 0],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 10, 47.29326012, 0],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 15, 51.41490358, 1],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 20, 52.60436695, 2],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 25, 54.55544168, 2],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 30, 57.14614388, 2],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 35, 59.45504074, 2],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 40, 60.86184431, 3],
#  ['c559', 'Zoniferol', 'Female', 19, 28, 45, 61.84005842, 4],
#  ['c580', 'Ketapril', 'Male', 22, 25, 0, 45.0, 0],
#  ['c580', 'Ketapril', 'Male', 22, 25, 5, 46.6284548, 0],
#  ['c580', 'Ketapril', 'Male', 22, 25, 10, 47.57017382, 1],
#  ['c580', 'Ketapril', 'Male', 22, 25, 15, 51.991708, 1],
#  ['c580', 'Ketapril', 'Male', 22, 25, 20, 55.57532195, 2],
#  ['c580', 'Ketapril', 'Male', 22, 25, 25, 56.28906231, 2],
#  ['c580', 'Ketapril', 'Male', 22, 25, 30, 58.04656941, 3],
#  ['c757', 'Placebo', 'Male', 9, 27, 0, 45.0, 0],
#  ['c757', 'Placebo', 'Male', 9, 27, 5, 47.78327981, 0],
#  ['c757', 'Placebo', 'Male', 9, 27, 10, 49.21931669, 0],
#  ['c757', 'Placebo', 'Male', 9, 27, 15, 51.532603, 0],
#  ['c757', 'Placebo', 'Male', 9, 27, 20, 52.81863401, 1],
#  ['c757', 'Placebo', 'Male', 9, 27, 25, 57.10641821, 2],
#  ['c757', 'Placebo', 'Male', 9, 27, 30, 60.09857184, 2],
#  ['c757', 'Placebo', 'Male', 9, 27, 35, 64.29116351, 2],
#  ['c757', 'Placebo', 'Male', 9, 27, 40, 66.60436771, 2],
#  ['c757', 'Placebo', 'Male', 9, 27, 45, 69.04284082, 3],
#  ['c766', 'Placebo', 'Female', 13, 26, 0, 45.0, 0],
#  ['c766', 'Placebo', 'Female', 13, 26, 5, 47.31305537, 0],
#  ['c766', 'Placebo', 'Female', 13, 26, 10, 49.50027098, 1],
#  ['c766', 'Placebo', 'Female', 13, 26, 15, 50.59663325, 2],
#  ['c766', 'Placebo', 'Female', 13, 26, 20, 53.00686463, 3],
#  ['c766', 'Placebo', 'Female', 13, 26, 25, 58.21462437, 3],
#  ['c766', 'Placebo', 'Female', 13, 26, 30, 60.2559245, 3],
#  ['c766', 'Placebo', 'Female', 13, 26, 35, 65.95236791, 4],
#  ['c766', 'Placebo', 'Female', 13, 26, 40, 67.68529456, 4],
#  ['c766', 'Placebo', 'Female', 13, 26, 45, 69.82314577, 4],
#  ['c819', 'Ketapril', 'Male', 21, 25, 0, 45.0, 0],
#  ['c819', 'Ketapril', 'Male', 21, 25, 5, 45.76924864, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 10, 46.65839527, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 15, 48.37099912, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 20, 49.76241475, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 25, 51.82835706, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 30, 56.0989982, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 35, 57.72953466, 1],
#  ['c819', 'Ketapril', 'Male', 21, 25, 40, 62.17570465, 1],
#  ['c832', 'Ketapril', 'Male', 18, 29, 0, 45.0, 0],
#  ['c832', 'Ketapril', 'Male', 18, 29, 5, 48.68546123, 1],
#  ['c832', 'Ketapril', 'Male', 18, 29, 10, 49.81141262, 1],
#  ['c832', 'Ketapril', 'Male', 18, 29, 15, 52.86453449, 1],
#  ['c832', 'Ketapril', 'Male', 18, 29, 20, 56.71023353, 1],
#  ['c832', 'Ketapril', 'Male', 18, 29, 25, 58.89181644, 2],
#  ['c832', 'Ketapril', 'Male', 18, 29, 30, 60.49637579, 2],
#  ['c832', 'Ketapril', 'Male', 18, 29, 35, 61.12448717, 2],
#  ['c832', 'Ketapril', 'Male', 18, 29, 40, 62.57231816, 2],
#  ['c832', 'Ketapril', 'Male', 18, 29, 45, 65.41595451, 3],
#  ['c895', 'Infubinol', 'Female', 7, 29, 0, 45.0, 0],
#  ['c895', 'Infubinol', 'Female', 7, 29, 5, 45.47754399, 0],
#  ['c895', 'Infubinol', 'Female', 7, 29, 10, 49.77901542, 0],
#  ['c895', 'Infubinol', 'Female', 7, 29, 15, 52.94946474, 1],
#  ['c895', 'Infubinol', 'Female', 7, 29, 20, 53.6768396, 2],
#  ['c895', 'Infubinol', 'Female', 7, 29, 25, 57.53419288, 2],
#  ['c895', 'Infubinol', 'Female', 7, 29, 30, 60.96971133, 2],
#  ['c927', 'Propriva', 'Female', 4, 26, 0, 45.0, 0],
#  ['c927', 'Propriva', 'Female', 4, 26, 5, 46.35184205, 0],
#  ['c927', 'Propriva', 'Female', 4, 26, 10, 50.96529767, 1],
#  ['c927', 'Propriva', 'Female', 4, 26, 15, 53.26643087, 1],
#  ['c927', 'Propriva', 'Female', 4, 26, 20, 55.48168922, 1],
#  ['c927', 'Propriva', 'Female', 4, 26, 25, 56.54551947, 2],
#  ['c927', 'Propriva', 'Female', 4, 26, 30, 60.7539246, 2],
#  ['c927', 'Propriva', 'Female', 4, 26, 35, 61.87227365, 3],
#  ['c927', 'Propriva', 'Female', 4, 26, 40, 64.18322918, 4],
#  ['d133', 'Zoniferol', 'Male', 5, 30, 0, 45.0, 0],
#  ['d164', 'Zoniferol', 'Male', 21, 28, 0, 45.0, 0],
#  ['d164', 'Zoniferol', 'Male', 21, 28, 5, 46.61767061, 0],
#  ['d164', 'Zoniferol', 'Male', 21, 28, 10, 47.47464468, 1],
#  ['d474', 'Ketapril', 'Male', 18, 27, 0, 45.0, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 5, 45.91835225, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 10, 46.97496297, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 15, 47.77793584, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 20, 51.73149416, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 25, 54.27932462, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 30, 55.34134157, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 35, 56.47911257, 0],
#  ['d474', 'Ketapril', 'Male', 18, 27, 40, 60.23373278, 1],
#  ['e213', 'Naftisol', 'Male', 8, 27, 0, 45.0, 0],
#  ['e213', 'Naftisol', 'Male', 8, 27, 5, 45.69925018, 1],
#  ['e213', 'Naftisol', 'Male', 8, 27, 10, 47.3915712, 2],
#  ['e213', 'Naftisol', 'Male', 8, 27, 15, 51.7916953, 2],
#  ['e213', 'Naftisol', 'Male', 8, 27, 20, 52.61376289, 2],
#  ['e213', 'Naftisol', 'Male', 8, 27, 25, 55.22447615, 2],
#  ['e213', 'Naftisol', 'Male', 8, 27, 30, 56.45872864, 3],
#  ['e213', 'Naftisol', 'Male', 8, 27, 35, 58.24585435, 3],
#  ['e213', 'Naftisol', 'Male', 8, 27, 40, 60.23654797, 3],
#  ['e213', 'Naftisol', 'Male', 8, 27, 45, 63.1056963, 4],
#  ['e227', 'Placebo', 'Male', 1, 30, 0, 45.0, 0],
#  ['e227', 'Placebo', 'Male', 1, 30, 5, 47.23801112, 0],
#  ['e227', 'Placebo', 'Male', 1, 30, 10, 51.34975705, 1],
#  ['e227', 'Placebo', 'Male', 1, 30, 15, 52.83394196, 1],
#  ['e227', 'Placebo', 'Male', 1, 30, 20, 56.6075521, 1],
#  ['e227', 'Placebo', 'Male', 1, 30, 25, 60.60029169, 1],
#  ['e227', 'Placebo', 'Male', 1, 30, 30, 62.46438515, 2],
#  ['e227', 'Placebo', 'Male', 1, 30, 35, 66.94912136, 3],
#  ['e227', 'Placebo', 'Male', 1, 30, 40, 70.7152176, 3],
#  ['e227', 'Placebo', 'Male', 1, 30, 45, 73.21293851, 3],
#  ['e291', 'Naftisol', 'Female', 14, 29, 0, 45.0, 0],
#  ['e291', 'Naftisol', 'Female', 14, 29, 5, 46.14250486, 0],
#  ['e291', 'Naftisol', 'Female', 14, 29, 10, 48.52974125, 1],
#  ['e291', 'Naftisol', 'Female', 14, 29, 15, 49.3484262, 1],
#  ['e291', 'Naftisol', 'Female', 14, 29, 20, 52.53376479, 1],
#  ['e291', 'Naftisol', 'Female', 14, 29, 25, 55.1389525, 2],
#  ['e476', 'Infubinol', 'Male', 23, 26, 0, 45.0, 0],
#  ['e476', 'Infubinol', 'Male', 23, 26, 5, 47.11180113, 0],
#  ['e476', 'Infubinol', 'Male', 23, 26, 10, 49.43168536, 0],
#  ['e476', 'Infubinol', 'Male', 23, 26, 15, 54.04621267, 0],
#  ['e476', 'Infubinol', 'Male', 23, 26, 20, 55.24927296, 0],
#  ['e476', 'Infubinol', 'Male', 23, 26, 25, 57.408638, 0],
#  ['e476', 'Infubinol', 'Male', 23, 26, 30, 57.99279743, 1],
#  ['e476', 'Infubinol', 'Male', 23, 26, 35, 60.0643402, 1],
#  ['e476', 'Infubinol', 'Male', 23, 26, 40, 61.52527583, 1],
#  ['e476', 'Infubinol', 'Male', 23, 26, 45, 62.43540402, 1],
#  ['e584', 'Naftisol', 'Male', 9, 27, 0, 45.0, 0],
#  ['e584', 'Naftisol', 'Male', 9, 27, 5, 45.6569785, 0],
#  ['e584', 'Naftisol', 'Male', 9, 27, 10, 47.25064148, 0],
#  ['e584', 'Naftisol', 'Male', 9, 27, 15, 48.43041053, 1],
#  ['e584', 'Naftisol', 'Male', 9, 27, 20, 50.34492095, 2],
#  ['e584', 'Naftisol', 'Male', 9, 27, 25, 51.38641908, 2],
#  ['e584', 'Naftisol', 'Male', 9, 27, 30, 54.98440767, 3],
#  ['e584', 'Naftisol', 'Male', 9, 27, 35, 58.08655989, 3],
#  ['e584', 'Naftisol', 'Male', 9, 27, 40, 62.81687083, 4],
#  ['e584', 'Naftisol', 'Male', 9, 27, 45, 68.3597767, 4],
#  ['f129', 'Zoniferol', 'Female', 11, 29, 0, 45.0, 0],
#  ['f129', 'Zoniferol', 'Female', 11, 29, 5, 47.00059399, 0],
#  ['f129', 'Zoniferol', 'Female', 11, 29, 10, 48.17971908, 1],
#  ['f129', 'Zoniferol', 'Female', 11, 29, 15, 49.98830246, 1],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 0, 45.0, 0],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 5, 47.31349062, 0],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 10, 47.90432375, 0],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 15, 48.73519714, 1],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 20, 51.11271293, 2],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 25, 52.17860221, 2],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 30, 56.87381654, 2],
#  ['f234', 'Stelasyn', 'Male', 14, 28, 35, 57.74875831, 2],
#  ['f278', 'Ketapril', 'Male', 12, 30, 0, 45.0, 0],
#  ['f278', 'Ketapril', 'Male', 12, 30, 5, 48.19457788, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 0, 45.0, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 5, 45.5911466, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 10, 47.22244619, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 15, 48.35223854, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 20, 49.61338303, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 25, 53.0788944, 0],
#  ['f345', 'Infubinol', 'Male', 23, 26, 30, 54.36379731, 1],
#  ['f345', 'Infubinol', 'Male', 23, 26, 35, 56.52332726, 1],
#  ['f345', 'Infubinol', 'Male', 23, 26, 40, 58.3155925, 1],
#  ['f345', 'Infubinol', 'Male', 23, 26, 45, 60.91876652, 1],
#  ['f394', 'Zoniferol', 'Male', 19, 30, 0, 45.0, 0],
#  ['f394', 'Zoniferol', 'Male', 19, 30, 5, 47.03309963, 0],
#  ['f436', 'Ceftamin', 'Female', 3, 25, 0, 45.0, 0],
#  ['f436', 'Ceftamin', 'Female', 3, 25, 5, 46.37079759, 1],
#  ['f436', 'Ceftamin', 'Female', 3, 25, 10, 48.14697758, 2],
#  ['f436', 'Ceftamin', 'Female', 3, 25, 15, 48.72207785, 2],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 0, 45.0, 0],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 5, 46.56581263, 0],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 10, 51.07251225, 0],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 15, 53.94554429, 1],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 20, 58.84118888, 1],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 25, 60.25348139, 1],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 30, 65.89398607, 1],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 35, 66.74292417, 1],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 40, 71.10811835, 1],
#  ['f545', 'Zoniferol', 'Female', 20, 26, 45, 73.32443228, 1],
#  ['f932', 'Ketapril', 'Male', 15, 29, 0, 45.0, 0],
#  ['f993', 'Naftisol', 'Male', 21, 28, 0, 45.0, 0],
#  ['f993', 'Naftisol', 'Male', 21, 28, 5, 46.39575966, 0],
#  ['f993', 'Naftisol', 'Male', 21, 28, 10, 48.18537323, 0],
#  ['f993', 'Naftisol', 'Male', 21, 28, 15, 49.10697473, 1],
#  ['f993', 'Naftisol', 'Male', 21, 28, 20, 52.07951009, 1],
#  ['g107', 'Ketapril', 'Female', 2, 29, 0, 45.0, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 5, 48.79166496, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 10, 53.43598668, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 15, 58.13554485, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 20, 62.70603145, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 25, 64.66362579, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 30, 69.16051982, 0],
#  ['g107', 'Ketapril', 'Female', 2, 29, 35, 71.90511721, 0],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 0, 45.0, 0],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 5, 46.59323337, 0],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 10, 48.26950861, 0],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 15, 49.65324404, 1],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 20, 51.4471183, 2],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 25, 55.6701066, 3],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 30, 57.99770642, 3],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 35, 60.38451978, 4],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 40, 62.22191493, 4],
#  ['g296', 'Zoniferol', 'Female', 14, 29, 45, 68.16319517, 4],
#  ['g497', 'Ketapril', 'Male', 19, 28, 0, 45.0, 0],
#  ['g497', 'Ketapril', 'Male', 19, 28, 5, 48.78206878, 0],
#  ['g497', 'Ketapril', 'Male', 19, 28, 10, 49.6470865, 0],
#  ['g497', 'Ketapril', 'Male', 19, 28, 15, 53.64616804, 1],
#  ['g497', 'Ketapril', 'Male', 19, 28, 20, 55.09699356, 1],
#  ['g497', 'Ketapril', 'Male', 19, 28, 25, 57.52444611, 2],
#  ['g497', 'Ketapril', 'Male', 19, 28, 30, 61.108186, 2],
#  ['g497', 'Ketapril', 'Male', 19, 28, 35, 64.0948893, 2],
#  ['g497', 'Ketapril', 'Male', 19, 28, 40, 67.74281406, 2],
#  ['g497', 'Ketapril', 'Male', 19, 28, 45, 69.87225079, 2],
#  ['g558', 'Propriva', 'Male', 8, 29, 0, 45.0, 0],
#  ['g558', 'Propriva', 'Male', 8, 29, 5, 46.18874193, 0],
#  ['g558', 'Propriva', 'Male', 8, 29, 10, 50.09475382, 0],
#  ['g558', 'Propriva', 'Male', 8, 29, 15, 51.007258, 0],
#  ['g558', 'Propriva', 'Male', 8, 29, 20, 55.09009691, 1],
#  ['g558', 'Propriva', 'Male', 8, 29, 25, 55.75408257, 2],
#  ['g558', 'Propriva', 'Male', 8, 29, 30, 58.95282911, 3],
#  ['g558', 'Propriva', 'Male', 8, 29, 35, 60.86215883, 4],
#  ['g558', 'Propriva', 'Male', 8, 29, 40, 61.77496268, 4],
#  ['g570', 'Propriva', 'Male', 16, 29, 0, 45.0, 0],
#  ['g570', 'Propriva', 'Male', 16, 29, 5, 47.65642436, 1],
#  ['g570', 'Propriva', 'Male', 16, 29, 10, 49.18823167, 1],
#  ['g570', 'Propriva', 'Male', 16, 29, 15, 52.6826954, 1],
#  ['g570', 'Propriva', 'Male', 16, 29, 20, 54.64329541, 1],
#  ['g570', 'Propriva', 'Male', 16, 29, 25, 56.8494056, 1],
#  ['g570', 'Propriva', 'Male', 16, 29, 30, 60.32871705, 1],
#  ['g570', 'Propriva', 'Male', 16, 29, 35, 62.3304204, 2],
#  ['g570', 'Propriva', 'Male', 16, 29, 40, 68.52585616, 2],
#  ['g570', 'Propriva', 'Male', 16, 29, 45, 70.49278763, 2],
#  ['g867', 'Stelasyn', 'Female', 9, 25, 0, 45.0, 0],
#  ['g867', 'Stelasyn', 'Female', 9, 25, 5, 46.88074916, 0],
#  ['g867', 'Stelasyn', 'Female', 9, 25, 10, 48.18340167, 0],
#  ['g867', 'Stelasyn', 'Female', 9, 25, 15, 51.06041924, 1],
#  ['h246', 'Ketapril', 'Male', 13, 30, 0, 45.0, 0],
#  ['h246', 'Ketapril', 'Male', 13, 30, 5, 49.47041702, 0],
#  ['h246', 'Ketapril', 'Male', 13, 30, 10, 51.36886216, 1],
#  ['h246', 'Ketapril', 'Male', 13, 30, 15, 56.18432701, 1],
#  ['h246', 'Ketapril', 'Male', 13, 30, 20, 57.93591218, 1],
#  ['h246', 'Ketapril', 'Male', 13, 30, 25, 59.5488537, 1],
#  ['h246', 'Ketapril', 'Male', 13, 30, 30, 63.59960954, 1],
#  ['h246', 'Ketapril', 'Male', 13, 30, 35, 67.2112701, 2],
#  ['h246', 'Ketapril', 'Male', 13, 30, 40, 71.15083468, 2],
#  ['h246', 'Ketapril', 'Male', 13, 30, 45, 74.10408567, 2],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 0, 45.0, 0],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 5, 45.75172728, 0],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 10, 46.23384414, 1],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 15, 50.69260358, 2],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 20, 51.99780618, 2],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 25, 53.73091434, 2],
#  ['h333', 'Stelasyn', 'Male', 21, 27, 30, 55.45528975, 2],
#  ['h428', 'Ketapril', 'Female', 1, 27, 0, 45.0, 0],
#  ['h531', 'Ceftamin', 'Male', 5, 27, 0, 45.0, 0],
#  ['h531', 'Ceftamin', 'Male', 5, 27, 5, 47.7846818, 0],
#  ['i386', 'Infubinol', 'Female', 23, 29, 0, 45.0, 0],
#  ['i386', 'Infubinol', 'Female', 23, 29, 5, 46.85369669, 1],
#  ['i386', 'Infubinol', 'Female', 23, 29, 10, 49.86154739, 2],
#  ['i386', 'Infubinol', 'Female', 23, 29, 15, 51.73656088, 2],
#  ['i386', 'Infubinol', 'Female', 23, 29, 20, 55.08772445, 2],
#  ['i386', 'Infubinol', 'Female', 23, 29, 25, 56.68786392, 3],
#  ['i386', 'Infubinol', 'Female', 23, 29, 30, 59.13364029, 3],
#  ['i386', 'Infubinol', 'Female', 23, 29, 35, 64.92542037, 3],
#  ['i386', 'Infubinol', 'Female', 23, 29, 40, 67.28962147, 4],
#  ['i477', 'Placebo', 'Female', 3, 30, 0, 45.0, 0],
#  ['i477', 'Placebo', 'Female', 3, 30, 5, 46.65738471, 0],
#  ['i477', 'Placebo', 'Female', 3, 30, 10, 47.52063206, 0],
#  ['i635', 'Propriva', 'Male', 21, 26, 0, 45.0, 0],
#  ['i635', 'Propriva', 'Male', 21, 26, 5, 47.23593715, 0],
#  ['i635', 'Propriva', 'Male', 21, 26, 10, 48.68575605, 1],
#  ['i635', 'Propriva', 'Male', 21, 26, 15, 49.53689775, 1],
#  ['i635', 'Propriva', 'Male', 21, 26, 20, 51.87706189, 1],
#  ['i635', 'Propriva', 'Male', 21, 26, 25, 52.92882323, 1],
#  ['i635', 'Propriva', 'Male', 21, 26, 30, 53.5970382, 2],
#  ['i635', 'Propriva', 'Male', 21, 26, 35, 55.67999656, 2],
#  ['i635', 'Propriva', 'Male', 21, 26, 40, 56.84243514, 3],
#  ['i635', 'Propriva', 'Male', 21, 26, 45, 58.63340414, 3],
#  ['i669', 'Placebo', 'Female', 18, 27, 0, 45.0, 0],
#  ['i669', 'Placebo', 'Female', 18, 27, 5, 46.76466824, 1],
#  ['i669', 'Placebo', 'Female', 18, 27, 10, 48.2816334, 1],
#  ['i669', 'Placebo', 'Female', 18, 27, 15, 48.8576007, 1],
#  ['i669', 'Placebo', 'Female', 18, 27, 20, 50.87369027, 1],
#  ['i669', 'Placebo', 'Female', 18, 27, 25, 53.30318455, 2],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 0, 45.0, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 5, 46.49302392, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 10, 50.42124982, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 15, 51.41964239, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 20, 55.97440502, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 25, 56.575195, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 30, 60.59185755, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 35, 62.12733561, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 40, 64.30345451, 0],
#  ['i901', 'Stelasyn', 'Male', 23, 29, 45, 65.34181087, 0],
#  ['j235', 'Placebo', 'Male', 6, 30, 0, 45.0, 0],
#  ['j235', 'Placebo', 'Male', 6, 30, 5, 46.58881978, 0],
#  ['j235', 'Placebo', 'Male', 6, 30, 10, 48.01878792, 1],
#  ['j235', 'Placebo', 'Male', 6, 30, 15, 51.16113815, 1],
#  ['j235', 'Placebo', 'Male', 6, 30, 20, 52.94290169, 1],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 0, 45.0, 0],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 5, 46.79925591, 1],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 10, 48.52997762, 2],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 15, 50.70127959, 2],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 20, 54.00534209, 3],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 25, 55.76714817, 3],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 30, 56.80306121, 3],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 35, 58.71448296, 3],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 40, 60.07268848, 3],
#  ['j296', 'Ceftamin', 'Female', 24, 30, 45, 61.84902336, 3],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 0, 45.0, 0],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 5, 46.7112611, 0],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 10, 48.34932028, 0],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 15, 49.58826336, 0],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 20, 50.93935278, 1],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 25, 51.8103204, 1],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 30, 54.40488176, 1],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 35, 56.96120016, 2],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 40, 62.32717066, 2],
#  ['j365', 'Zoniferol', 'Male', 24, 28, 45, 64.29408493, 2],
#  ['j755', 'Naftisol', 'Male', 23, 27, 0, 45.0, 0],
#  ['j755', 'Naftisol', 'Male', 23, 27, 5, 47.24284357, 0],
#  ['j755', 'Naftisol', 'Male', 23, 27, 10, 48.16706083, 0],
#  ['j755', 'Naftisol', 'Male', 23, 27, 15, 51.45397391, 0],
#  ['j755', 'Naftisol', 'Male', 23, 27, 20, 55.49660753, 1],
#  ['j755', 'Naftisol', 'Male', 23, 27, 25, 58.05581822, 1],
#  ['j755', 'Naftisol', 'Male', 23, 27, 30, 60.00720978, 1],
#  ['j755', 'Naftisol', 'Male', 23, 27, 35, 62.7328576, 1],
#  ['j755', 'Naftisol', 'Male', 23, 27, 40, 67.2077103, 1],
#  ...]

# %%
#Preparing data: Dictionary Option, Turning dataframe into a list of dictionaries to use with pyplot.
clean_data_df.to_dict(orient='records')
clean_data_dict = clean_data_df
clean_data_dict
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
print(clean_data_dict)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender


# Make the pie chart

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender


# Make the pie chart

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers.


    # Locate the rows which contain mice on each drug and get the tumor volumes


    # add subset


    # Determine outliers using upper and lower bounds
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
